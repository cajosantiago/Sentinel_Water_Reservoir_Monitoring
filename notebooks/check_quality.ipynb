# %%
import numpy as np

x=np.load('/home/csantiago/generated_data/quality/Maranhão/20221215T113029Z_cc10.9pct_turbidity_NTU.npy')
x=np.load('/home/csantiago/generated_data/quality/Maranhão/20221125T113025Z_cc0.2pct_turbidity_NTU.npy')

# %%
import matplotlib.pyplot as plt

plt.imshow(x)
